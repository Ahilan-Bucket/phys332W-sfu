# %%
lam = 5.5e-7
v = 1e-4   # v/c
L = 11     # meters

def N(lam, v, L):
    return (2*L/lam) * v**2

print(N(lam, v, L))
# Out:
# 0.4

# %% [markdown]
# TO detect a shift of 1/100, how fast should ether have been moving?
# Assuming, the same L and Lambda
