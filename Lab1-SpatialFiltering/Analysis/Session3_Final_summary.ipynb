# %% [markdown]
# # Required Submission Summary
# **Spatial Filtering Lab — Full Notebook (Sessions 1–3)**
# **Date Range:** January 8–15, 2026
# **Student:** Ahilan Kumaresan
# **Lab Partner:** Nathan
#
# This summary lists the key work completed during each lab week, with page references to guide grading.
#
# ---
#
# ## Week 1 — Snapshot 1 (Explore)
#
# ### Pre-lab preparation and theory
# - **Pre-lab Q1: Köhler illumination calculations**
#   Field stop diameter calculation, aperture stop (pinhole) resolution criterion, and spectral broadening limit derived and evaluated numerically.
#   *Pages:* **[   ]**
#
# - **Pre-lab Q2: Ronchi ruling diffraction theory**
#   Full derivation of the diffraction intensity pattern
#   $$I(\theta) = I_0 \left(\frac{\sin \beta}{\beta}\right)^2 \left(\frac{\sin N\alpha}{\sin \alpha}\right)^2$$
#   including envelope vs. interference terms, duty cycle effects, and finite source/bandwidth discussion.
#   *Pages:* **[   ]**
#
# ### Goals and planning
# - **Explicit session goals and intermediate goals**
#   Alignment, magnification verification, uncertainty identification.
#   *Pages:* **[   ]**
#
# ### Initial setup and alignment
# - **LED, camera, and magnification lens alignment**
#   Sharp focus achieved; rail distances measured with defined uncertainty.
#   *Pages:* **[   ]**
#
# - **Apparatus sketch with labeled planes**
#   Object plane, Fourier plane (back focal plane), and image plane identified.
#   *Pages:* **[   ]**
#
# ### Illumination debugging (critical troubleshooting)
# - **Quick-check: illumination uniformity**
#   White-card test used to localize onset of non-uniform illumination.
#   *Pages:* **[   ]**
#
# - **Root cause and correction**
#   Incorrect lens orientations (L3/L4) diagnosed; element-by-element correction performed without full disassembly.
#   *Pages:* **[   ]**
#
# ### Session reflection
# - **Post-lab reflection (Week 1)**
#   Evaluation of pacing, alignment strategy, and procedural improvements.
#   *Pages:* **[   ]**
#
# ---
#
# ## Week 2 — Snapshot 2 (Optimize)
#
# ### Completion of Köhler illumination
# - **Field lens and aperture stop configuration**
#   LED imaged onto pinhole; field stop set to ~5 mm illuminated area at object.
#   *Pages:* **[   ]**
#
# - **Stray light mitigation**
#   Additional iris and camera lens tube installed to suppress ambient light.
#   *Pages:* **[   ]**
#
# ### Resolution testing
# - **Ronchi grating imaging (real space)**
#   Resolution limit tested; lp/mm values recorded and compared qualitatively to expectations.
#   *Pages:* **[   ]**
#
# ### Uncertainty identification
# - **Random and systematic uncertainties**
#   Rail measurement limits, alignment sensitivity, lens tolerances, camera artifacts identified.
#   *Pages:* **[   ]**
#
# ### Session reflection
# - **Post-lab reflection (Week 2)**
#   Identification of remaining limitations and optimization strategies.
#   *Pages:* **[   ]**
#
# ---
#
# ## Week 3 — Session 3 (Complete)
#
# ### Fourier-plane analysis
# - **Fourier plane location**
#   Back focal plane identified using viewing card; rail coordinate recorded.
#   *Pages:* **[   ]**
#
# - **Camera placement at Fourier plane**
#   Stable diffraction pattern observed and recorded.
#   *Pages:* **[   ]**
#
# ### Quantitative measurements
# - **Real-space magnification measurement**
#   Pixel-to-millimeter conversion using 10 lp/mm Ronchi grating.
#   $$M = \frac{\text{image size}}{\text{object size}}$$
#   *Pages:* **[   ]**
#
# - **Diffraction order spacing measurement**
#   Order positions measured in pixels and converted to physical spacing.
#   *Pages:* **[   ]**
#
# ### Comparison with theory
# - **Grating equation check**
#   $$d\sin\theta_m = m\lambda$$
#   Experimental order spacing compared to theoretical prediction; discrepancies discussed.
#   *Pages:* **[   ]**
#
# ### Final reflection and outlook
# - **Assessment of measurement quality and limitations**
#   Impact of alignment, finite bandwidth, and illumination non-uniformity discussed.
#   *Pages:* **[   ]**
#
# - **Plan for future analysis**
#   Line-profile extraction, contrast calculation, and modulation transfer function (MTF) estimation outlined.
#   *Pages:* **[   ]**
#
# ---
#
# ## Final Results Summary (for full notebook submission)
#
# - Köhler illumination successfully established and debugged.
# - Real-space and Fourier-space imaging achieved.
# - Magnification measured and compared to design value.
# - Diffraction order spacing measured and compared quantitatively with theory.
# - Dominant sources of uncertainty identified and partially mitigated.
